# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
# Personalized Music Recommendation System
#
# This notebook analyzes the Last.fm 360K dataset and HetRec 2011 dataset to drive preprocessing and modeling decisions.

# %%
# %run 01_eda.py
